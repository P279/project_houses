# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_excel('/Users/padminiyadav/Downloads/sold_cust.xls')

# %%
df  =df[8:-4]

# %%
df.columns = ['year', 'total_units_sold','Unnamed: 2','Unnamed: 3','Unnamed: ','Unnamed: 5']

# %%
df.set_index('year', inplace = True)

# %%
for i in df:
    df[f'{i}'] = pd.to_numeric(df[f'{i}'])

# %%
df = df.loc[2001:]['total_units_sold']

# %%
df
# Out:
# year
# 2001     908
# 2002     973
# 2003    1086
# 2004    1203
# 2005    1283
# 2006    1051
# 2007     776
# 2008     485
# 2009     375
# 2010     323
# 2011     306
# 2012     368
# 2013     429
# 2014     437
# 2015     501
# 2016     561
# 2017     613
# 2018     617
# 2019     683
# 2020     822
# 2021     771
# Name: total_units_sold, dtype: int64

# %%
df1 = pd.read_excel('/Users/padminiyadav/Downloads/unemp.xlsx')

# %%
df1 = df1[11:]

# %%
df1.columns = ['year', 'jan','feb','mar', 'apr', 'may','jun','jul','aug','sep','oct','nov','dec']

# %%
df1
# Out:
#     year  jan  feb  mar   apr   may  jun   jul  aug  sep  oct  nov  dec
# 11  2001  4.2  4.2  4.3   4.4   4.3  4.5   4.6  4.9    5  5.3  5.5  5.7
# 12  2002  5.7  5.7  5.7   5.9   5.8  5.8   5.8  5.7  5.7  5.7  5.9    6
# 13  2003  5.8  5.9  5.9     6   6.1  6.3   6.2  6.1  6.1    6  5.8  5.7
# 14  2004  5.7  5.6  5.8   5.6   5.6  5.6   5.5  5.4  5.4  5.5  5.4  5.4
# 15  2005  5.3  5.4  5.2   5.2   5.1    5     5  4.9    5    5    5  4.9
# 16  2006  4.7  4.8  4.7   4.7   4.6  4.6   4.7  4.7  4.5  4.4  4.5  4.4
# 17  2007  4.6  4.5  4.4   4.5   4.4  4.6   4.7  4.6  4.7  4.7  4.7    5
# 18  2008    5  4.9  5.1     5   5.4  5.6   5.8  6.1  6.1  6.5  6.8  7.3
# 19  2009  7.8  8.3  8.7     9   9.4  9.5   9.5  9.6  9.8   10  9.9  9.9
# 20  2010  9.8  9.8  9.9   9.9   9.6  9.4   9.4  9.5  9.5  9.4  9.8  9.3
# 21  2011  9.1    9    9   9.1     9  9.1     9    9    9  8.8  8.6  8.5
# 22  2012  8.3  8.3  8.2   8.2   8.2  8.2   8.2  8.1  7.8  7.8  7.7  7.9
# ...

# %%
for i in df1:
    df1[f'{i}'] = pd.to_numeric(df1[f'{i}'])

# %%
df1.set_index('year', inplace = True)

# %%
s = ''
for i in df1.columns:
    s+= f"row['{i}']+"
    
s=s[:-1]

# %%
df1['avg'] = df1.apply(lambda row: round((row['jan']+row['feb']+row['mar']+row['apr']+row['may']+row['jun']+row['jul']+row['aug']+row['sep']+row['oct']+row['nov']+row['dec'])/12,2), axis=1)

# %%
df1
# Out:
#       jan  feb  mar   apr   may   jun   jul  aug  sep   oct  nov  dec   avg
# year
# 2001  4.2  4.2  4.3   4.4   4.3   4.5   4.6  4.9  5.0   5.3  5.5  5.7  4.74
# 2002  5.7  5.7  5.7   5.9   5.8   5.8   5.8  5.7  5.7   5.7  5.9  6.0  5.78
# 2003  5.8  5.9  5.9   6.0   6.1   6.3   6.2  6.1  6.1   6.0  5.8  5.7  5.99
# 2004  5.7  5.6  5.8   5.6   5.6   5.6   5.5  5.4  5.4   5.5  5.4  5.4  5.54
# 2005  5.3  5.4  5.2   5.2   5.1   5.0   5.0  4.9  5.0   5.0  5.0  4.9  5.08
# 2006  4.7  4.8  4.7   4.7   4.6   4.6   4.7  4.7  4.5   4.4  4.5  4.4  4.61
# 2007  4.6  4.5  4.4   4.5   4.4   4.6   4.7  4.6  4.7   4.7  4.7  5.0  4.62
# 2008  5.0  4.9  5.1   5.0   5.4   5.6   5.8  6.1  6.1   6.5  6.8  7.3  5.80
# 2009  7.8  8.3  8.7   9.0   9.4   9.5   9.5  9.6  9.8  10.0  9.9  9.9  9.28
# 2010  9.8  9.8  9.9   9.9   9.6   9.4   9.4  9.5  9.5   9.4  9.8  9.3  9.61
# 2011  9.1  9.0  9.0   9.1   9.0   9.1   9.0  9.0  9.0   8.8  8.6  8.5  8.93
# ...

# %%
df2= pd.concat([df,df1['avg']], axis = 1)
df2.corr()
# Out:
#                   total_units_sold       avg
# total_units_sold          1.000000 -0.509793
# avg                      -0.509793  1.000000

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
sdf = scaler.fit_transform(df2)

# %%
sdf
# Out:
# array([[ 0.73480975, -0.75135311],
#        [ 0.95785073, -0.15637298],
#        [ 1.34559891, -0.03623276],
#        [ 1.74707268, -0.29367609],
#        [ 2.02158466, -0.55684038],
#        [ 1.22549991, -0.82572563],
#        [ 0.28186498, -0.82000466],
#        [-0.71667235, -0.14493106],
#        [-1.09412632,  1.84596399],
#        [-1.27255911,  2.03475576],
#        [-1.33089291,  1.64573029],
#        [-1.11814612,  1.15944845],
#        [-0.90883074,  0.74753914],
#        [-0.88137954,  0.0610236 ],
#        [-0.66176995, -0.44242112],
#        [-0.45588597, -0.67125963],
#        [-0.27745318, -0.9687497 ],
#        [-0.26372758, -1.23763495],
#        [-0.0372552 , -1.35777516],
#        [ 0.43970937,  1.16516942],
#        [ 0.26470798, -0.39665342]])

# %%
l = [i for i in range(2000,2022)]

# %%
l
# Out:
# [2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021]

# %%
plt.figure(figsize = (16,5))
plt.plot(sdf)
plt.legend(['total houses sold', 'unemployment rate'])
plt.title('comapritive growth (scaled)')
plt.xlabel('year since 2000')
plt.axvline(8, color='red', linestyle = '-')
plt.axvline(8.1, color='red', linestyle = '-')
plt.show()

# %%
pd.DataFrame(sdf)
# Out:
#            0         1
# 0   0.734810 -0.751353
# 1   0.957851 -0.156373
# 2   1.345599 -0.036233
# 3   1.747073 -0.293676
# 4   2.021585 -0.556840
# 5   1.225500 -0.825726
# 6   0.281865 -0.820005
# 7  -0.716672 -0.144931
# 8  -1.094126  1.845964
# 9  -1.272559  2.034756
# 10 -1.330893  1.645730
# 11 -1.118146  1.159448
# 12 -0.908831  0.747539
# 13 -0.881380  0.061024
# 14 -0.661770 -0.442421
# 15 -0.455886 -0.671260
# 16 -0.277453 -0.968750
# 17 -0.263728 -1.237635
# 18 -0.037255 -1.357775
# 19  0.439709  1.165169
# 20  0.264708 -0.396653

# %%
plt.scatter(df2['total_units_sold'],df2['avg'])

# %%
X = np.array(df2['total_units_sold'])
y = np.array(df2['avg'])

# %%
df2['avg']
# Out:
# year
# 2001    4.74
# 2002    5.78
# 2003    5.99
# 2004    5.54
# 2005    5.08
# 2006    4.61
# 2007    4.62
# 2008    5.80
# 2009    9.28
# 2010    9.61
# 2011    8.93
# 2012    8.08
# 2013    7.36
# 2014    6.16
# 2015    5.28
# 2016    4.88
# 2017    4.36
# 2018    3.89
# 2019    3.68
# 2020    8.09
# 2021    5.36
# Name: avg, dtype: float64

# %%
coefs = np.polyfit(X, y, 3)

# %%
print(coefs)
p = np.poly1d(coefs)
plt.plot(X, y, "bo", markersize= 3)
plt.plot(X, p(X), "ro-", markersize = 3)
plt.xlabel('total houses sold in the year')
plt.ylabel('avg unemployment rate of the year')
plt.show()
# Out:
# [-3.75946854e-08  9.97912987e-05 -8.36241550e-02  2.72022522e+01]

# %%
from sklearn import metrics
print('R^2:',metrics.r2_score(p(X), y))
print('MAE:',metrics.mean_absolute_error(p(X), y))
print('MSE:',metrics.mean_squared_error(p(X), y))
print('RMSE:',np.sqrt(metrics.mean_squared_error(p(X), y)))
# Out:
# R^2: 0.623186364075526
# MAE: 0.6085634864197557
# MSE: 0.8362058639533368
# RMSE: 0.9144429254761266

# %%
plt.scatter(X, y, color = 'blue')
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'red')
plt.show()

# %%
plt.scatter(X, y, color = 'blue')
 
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'red')
plt.title('Polynomial Regression')
 
plt.show()

# %% [markdown]
# ## RESULT
# ### AVERAGELY STRONG INVERSE RELATION IN NO. OF HOUSES & UNEMP RATE (Corr. coeff = -0.509)

# %%
ar = pd.read_excel('/Users/padminiyadav/Downloads/price.xls')

# %%
ar
# Out:
#    Median and Average Sales Price of Houses Sold by Region  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                              Period
# 3                                                 NaN
# 4                                                1963
# ..                                                ...
# 58                                               2017
# 59                                               2018
# 60                                               2019
# 61                                               2020
# 62                                               2021
#
#             Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                  NaN        NaN        NaN        NaN        NaN
# 1   Median sales price        NaN        NaN        NaN        NaN
# 2              United   Northeast    Midwest      South       West
# ...

# %%
ar.columns = ['year', 'median_price','NE', 'MW', 'S', 'W', 'Unnamed: 6','Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10']

# %%
ar = ar[42:]

# %%
ar.columns
# Out:
# Index(['year', 'median_price', 'NE', 'MW', 'S', 'W', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %%
ar.drop(['Unnamed: 6','Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], axis=1, inplace=True)

# %%
ar.head(2)
# Out:
#     year median_price      NE      MW       S       W
# 42  2001       175200  246400  172600  155400  213600
# 43  2002       187600  264300  178000  163400  238500

# %%
ar.set_index('year',inplace =True)

# %%
plt.figure(figsize = (16,5))
plt.plot(ar.median_price, linewidth = 4)
plt.plot(ar.NE,linestyle='dashed')
plt.plot(ar.MW,linestyle='dashed')
plt.plot(ar.S,linestyle='dashed')
plt.plot(ar.W,linestyle='dashed')
plt.legend(['median','NE','MW','S','W'], loc = 'lower right')
plt.xticks(np.arange(2001, 2022, 1.0))
plt.show()

# %% [markdown]
# ## RESULT
#
# ### Houses acc to region are in price order: NE>W>MW~=S

# %%
dfs = pd.read_excel('/Users/padminiyadav/Downloads/share.xls')

# %%
dfsp = dfs[29:-9]

# %%
dfsp
# Out:
#    Unnamed: 0                  Unnamed: 1        Unnamed: 2  \
# 29        NaN  Combined Enterprise Share   Fannie Mae Share
# 30       1990                    0.256734          0.139855
# 31       1991                    0.284616          0.158339
# 32       1992                    0.318728          0.181332
# 33       1993                    0.343459          0.196584
# 34       1994                    0.350209          0.199768
# 35       1995                    0.358464          0.206156
# 36       1996                    0.365668          0.211207
# 37       1997                    0.365731          0.213268
# 38       1998                    0.388851          0.229095
# 39       1999                    0.408552          0.237978
# 40       2000                    0.414851          0.239053
# 41       2001                    0.447369          0.258807
# 42       2002                    0.454927          0.266843
# 43       2003                    0.462606          0.283358
# ...

# %%
dfsp.drop('Unnamed: 4', axis=1,inplace = True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dfsp.loc[29].values
# Out:
# array([nan, 'Combined Enterprise Share ', 'Fannie Mae Share',
#        'Freddie Mac Share'], dtype=object)

# %%
dfsp.columns = ['year','Combined Enterprise Share ', 'Fannie Mae Share','Freddie Mac Share']

# %%
dfsp.drop(index = 29, inplace = True)

# %%
dfsp.set_index('year', inplace= True)

# %%
dfsp = dfsp.apply(lambda row: row*100)

# %%
dfsp
# Out:
#      Combined Enterprise Share  Fannie Mae Share Freddie Mac Share
# year
# 1990                    25.6734          13.9855           11.6879
# 1991                    28.4616          15.8339           12.6277
# 1992                    31.8728          18.1332           13.7396
# 1993                    34.3459          19.6584           14.6875
# 1994                    35.0209          19.9768           15.0441
# 1995                    35.8464          20.6156           15.2308
# 1996                    36.5668          21.1207           15.4461
# 1997                    36.5731          21.3268           15.2463
# 1998                    38.8851          22.9095           15.9756
# 1999                    40.8552          23.7978           17.0574
# 2000                    41.4851          23.9053           17.5798
# 2001                    44.7369          25.8807           18.8562
# 2002                    45.4927          26.6843           18.8085
# ...

# %%
dfsp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 1990 to 2010
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Combined Enterprise Share   21 non-null     object
#  1   Fannie Mae Share            21 non-null     object
#  2   Freddie Mac Share           21 non-null     object
# dtypes: object(3)
# memory usage: 672.0+ bytes

# %%
for i in dfsp:
    dfsp[f'{i}'] = pd.to_numeric(dfsp[f'{i}'])

# %%
plt.figure(figsize = (16,5))
plt.plot(dfsp)
plt.xticks(np.arange(1990, 2010, 1.0))
plt.legend(['Combined Enterprise Share','Fannie Mae Share ','Freddie Mac Share'])
plt.show()

# %%
dfs = dfs[4:25]

# %%
dfs.drop('Unnamed: 4', axis=1,inplace = True)
dfs.columns = ['year','Combined Enterprise Share ', 'Fannie Mae Share','Freddie Mac Share']

# %%
dfs
# Out:
#      year Combined Enterprise Share  Fannie Mae Share Freddie Mac Share
# 4    1990                     404703           338217            742920
# 5    1991                     484267           386209            870476
# 6    1992                     582563           441410           1023973
# 7    1993                     662167           494727           1156894
# 8    1994                     708402           533484           1241886
# 9    1995                     766741           566469           1333210
# 10   1996                     835225           610820           1446045
# 11   1997                     895816           640406           1536222
# 12   1998                    1051658           733360           1785018
# 13   1999                    1203086           862326           2065412
# 14   2000                    1316844           968399           2285243
# 15   2001                    1579398          1150723           2730121
# ...

# %%
dfs.set_index('year', inplace= True)

# %%
for i in dfs:
    dfs[f'{i}'] = pd.to_numeric(dfs[f'{i}'])

# %%
plt.figure(figsize = (16,5))
plt.plot(dfsp)
plt.xticks(np.arange(1990, 2010, 1.0))
plt.legend(['Combined Enterprise Share','Fannie Mae Share ','Freddie Mac Share'])
plt.show()

# %%
rts = pd.read_excel('/Users/padminiyadav/Downloads/spr1.xlsx')

# %%
rts
# Out:
#                Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                     NaN        NaN        NaN
# 1                     NaN        NaN        NaN
# 2                     NaN        NaN        NaN
# 3                     NaN       U.S.      30 yr
# 4                     NaN      30 yr     fees &
# ...                   ...        ...        ...
# 2650  2021-12-02 00:00:00       3.11        0.6
# 2651  2021-12-09 00:00:00        3.1        0.7
# 2652  2021-12-16 00:00:00       3.12        0.6
# 2653  2021-12-23 00:00:00       3.05        0.7
# 2654  2021-12-30 00:00:00       3.11        0.7
#
#                                             Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                      PRIMARY MORTGAGE MARKET SURVEY®        NaN        NaN
# 1     Summary page with all rate types - U.S. averages        NaN        NaN
# 2                                                  NaN        NaN        NaN
# ...

# %%
rts = rts[1750:]

# %%
rts
# Out:
#                Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 1750  2004-09-02 00:00:00       5.77        0.8       5.15        0.7
# 1751  2004-09-09 00:00:00       5.83        0.8       5.22        0.8
# 1752  2004-09-16 00:00:00       5.75        0.8       5.13        0.8
# 1753  2004-09-23 00:00:00        5.7        0.7        5.1        0.7
# 1754  2004-09-30 00:00:00       5.72        0.6       5.12        0.6
# ...                   ...        ...        ...        ...        ...
# 2650  2021-12-02 00:00:00       3.11        0.6       2.39        0.6
# 2651  2021-12-09 00:00:00        3.1        0.7       2.38        0.7
# 2652  2021-12-16 00:00:00       3.12        0.6       2.34        0.7
# 2653  2021-12-23 00:00:00       3.05        0.7        2.3        0.7
# 2654  2021-12-30 00:00:00       3.11        0.7       2.33        0.7
#
#      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 1750        NaN        NaN        NaN        NaN
# ...

# %%
rts.fillna(0, inplace = True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
for i in rts:
    rts[f'{i}'] = pd.to_numeric(rts[f'{i}'])
# Out:
# <ipython-input-54-c99c5ba430fa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rts[f'{i}'] = pd.to_numeric(rts[f'{i}'])

# %%
rts['date'] = pd.to_datetime(rts['Unnamed: 0'])
# Out:
# <ipython-input-55-ad856938a183>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rts['date'] = pd.to_datetime(rts['Unnamed: 0'])

# %%
rts.drop('Unnamed: 0', inplace = True, axis = 1)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
rts
# Out:
#       Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 1750        5.77         0.8        5.15         0.7        0.00         0.0
# 1751        5.83         0.8        5.22         0.8        0.00         0.0
# 1752        5.75         0.8        5.13         0.8        0.00         0.0
# 1753        5.70         0.7        5.10         0.7        0.00         0.0
# 1754        5.72         0.6        5.12         0.6        0.00         0.0
# ...          ...         ...         ...         ...         ...         ...
# 2650        3.11         0.6        2.39         0.6        2.49         0.3
# 2651        3.10         0.7        2.38         0.7        2.45         0.3
# 2652        3.12         0.6        2.34         0.7        2.45         0.3
# 2653        3.05         0.7        2.30         0.7        2.37         0.4
# 2654        3.11         0.7        2.33         0.7        2.41         0.5
#
#       Unnamed: 7  Unnamed: 8       date
# ...

# %%
rts.set_index('date', inplace = True)

# %%
rts
# Out:
#             Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# date
# 2004-09-02        5.77         0.8        5.15         0.7        0.00
# 2004-09-09        5.83         0.8        5.22         0.8        0.00
# 2004-09-16        5.75         0.8        5.13         0.8        0.00
# 2004-09-23        5.70         0.7        5.10         0.7        0.00
# 2004-09-30        5.72         0.6        5.12         0.6        0.00
# ...                ...         ...         ...         ...         ...
# 2021-12-02        3.11         0.6        2.39         0.6        2.49
# 2021-12-09        3.10         0.7        2.38         0.7        2.45
# 2021-12-16        3.12         0.6        2.34         0.7        2.45
# 2021-12-23        3.05         0.7        2.30         0.7        2.37
# 2021-12-30        3.11         0.7        2.33         0.7        2.41
#
#             Unnamed: 6  Unnamed: 7  Unnamed: 8
# date
# 2004-09-02         0.0        0.00        0.00
# ...

# %%
plt.figure(figsize = (16,5))
plt.plot(rts)
plt.show()

# %%
rts
# Out:
#             Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# date
# 2004-09-02        5.77         0.8        5.15         0.7        0.00
# 2004-09-09        5.83         0.8        5.22         0.8        0.00
# 2004-09-16        5.75         0.8        5.13         0.8        0.00
# 2004-09-23        5.70         0.7        5.10         0.7        0.00
# 2004-09-30        5.72         0.6        5.12         0.6        0.00
# ...                ...         ...         ...         ...         ...
# 2021-12-02        3.11         0.6        2.39         0.6        2.49
# 2021-12-09        3.10         0.7        2.38         0.7        2.45
# 2021-12-16        3.12         0.6        2.34         0.7        2.45
# 2021-12-23        3.05         0.7        2.30         0.7        2.37
# 2021-12-30        3.11         0.7        2.33         0.7        2.41
#
#             Unnamed: 6  Unnamed: 7  Unnamed: 8
# date
# 2004-09-02         0.0        0.00        0.00
# ...

# %%
train = rts[rts.index < "2018-11-01"]
test = rts[rts.index > "2018-11-01"]

# %%
plt.plot(train, color = "black")
plt.plot(test, color = "red")

plt.xticks(rotation=45)
plt.title("Train/Test split for Data")
plt.show()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
y = train['Unnamed: 1']

# %%
ARMAmodel = SARIMAX(y, order=(1,0,1))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
ARMAmodel = ARMAmodel.fit()

# %%
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha = 0.05) 
y_pred_df["Predictions"] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:376: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:376: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'

# %%
plt.plot(train, color = "black")
plt.plot(test, color = "red")
plt.plot(y_pred_out, color='green', label = 'Predictions')
plt.legend()
plt.xticks(rotation=45)
plt.title("Train/Test split for Data")
plt.show()

# %%
y2 = train['Unnamed: 3']

# %%
ARMAmodel = SARIMAX(y2, order=(1,0,1))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
ARMAmodel = ARMAmodel.fit()

# %%
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha = 0.05)
y_pred_df["Predictions"] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:376: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:376: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'

# %%
plt.plot(train['Unnamed: 3'], color = "black")
plt.plot(test['Unnamed: 3'], color = "red")
plt.plot(y_pred_out, color='green', label = 'Predictions')
plt.legend()
plt.xticks(rotation=45)
plt.title("30-year Mortgage rates by year")
plt.show()

# %%
rts
# Out:
#             Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# date
# 2004-09-02        5.77         0.8        5.15         0.7        0.00
# 2004-09-09        5.83         0.8        5.22         0.8        0.00
# 2004-09-16        5.75         0.8        5.13         0.8        0.00
# 2004-09-23        5.70         0.7        5.10         0.7        0.00
# 2004-09-30        5.72         0.6        5.12         0.6        0.00
# ...                ...         ...         ...         ...         ...
# 2021-12-02        3.11         0.6        2.39         0.6        2.49
# 2021-12-09        3.10         0.7        2.38         0.7        2.45
# 2021-12-16        3.12         0.6        2.34         0.7        2.45
# 2021-12-23        3.05         0.7        2.30         0.7        2.37
# 2021-12-30        3.11         0.7        2.33         0.7        2.41
#
#             Unnamed: 6  Unnamed: 7  Unnamed: 8
# date
# 2004-09-02         0.0        0.00        0.00
# ...

# %%
rts['date'] = pd.to_datetime(rts.index)
# Out:
# <ipython-input-76-f4db7bc4aa41>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rts['date'] = pd.to_datetime(rts.index)

# %%
rts.groupby(rts.date.dt.year)['Unnamed: 1'].median()
# Out:
# date
# 2004    5.740
# 2005    5.785
# 2006    6.385
# 2007    6.270
# 2008    6.040
# 2009    5.035
# 2010    4.735
# 2011    4.510
# 2012    3.660
# 2013    4.115
# 2014    4.140
# 2015    3.860
# 2016    3.590
# 2017    3.945
# 2018    4.550
# 2019    3.795
# 2020    3.070
# 2021    2.975
# Name: Unnamed: 1, dtype: float64

# %%
df[3:]
# Out:
# year
# 2004    1203
# 2005    1283
# 2006    1051
# 2007     776
# 2008     485
# 2009     375
# 2010     323
# 2011     306
# 2012     368
# 2013     429
# 2014     437
# 2015     501
# 2016     561
# 2017     613
# 2018     617
# 2019     683
# 2020     822
# 2021     771
# Name: total_units_sold, dtype: int64

# %%
plt.figure(figsize = (16,5))
plt.plot(rts.groupby(rts.date.dt.year)['Unnamed: 1'].mean())
plt.legend(['Mortgage rate'])
plt.show()
plt.figure(figsize = (16,5))
plt.plot(df[3:])
plt.legend(['Units sold'])
plt.show()

# %%
for i in range(1,9):
    print(i,' --> ', pd.concat([df[3:], rts.groupby(rts.date.dt.year)[f'Unnamed: {i}'].mean()], axis =1).corr().values[0][1])
# Out:
# 1  -->  0.4210474031576394
# 2  -->  -0.3159580678350684
# 3  -->  0.447385100649461
# 4  -->  -0.25548032835885015
# 5  -->  0.032228455179711325
# 6  -->  -0.4599594168400086
# 7  -->  -0.46066792017852354
# 8  -->  -0.030470476139914025

# %%
from sklearn import preprocessing
n1 = preprocessing.normalize([df[3:]])
n2 = preprocessing.normalize([rts.groupby(rts.date.dt.year)['Unnamed: 6'].mean()])
n3 = preprocessing.normalize([rts.groupby(rts.date.dt.year)['Unnamed: 3'].mean()])

# %%
plt.figure(figsize = (16,5))
plt.plot(n1[0])
plt.plot(n2[0])
plt.plot(n3[0])
plt.show()

# %%
new_houses = pd.read_csv('/Users/padminiyadav/Downloads/HOUST (1).csv')

# %%
new_houses['DATE'] = pd.to_datetime(new_houses['DATE'])

# %%
plt.figure(figsize = (18,5))
plt.plot(new_houses.groupby(new_houses.DATE.dt.year).mean())
plt.plot(new_houses.groupby(new_houses.DATE.dt.year).median())
plt.xticks(range(1980,2023,1), rotation =45)
plt.show()

# %%
df
# Out:
# year
# 2001     908
# 2002     973
# 2003    1086
# 2004    1203
# 2005    1283
# 2006    1051
# 2007     776
# 2008     485
# 2009     375
# 2010     323
# 2011     306
# 2012     368
# 2013     429
# 2014     437
# 2015     501
# 2016     561
# 2017     613
# 2018     617
# 2019     683
# 2020     822
# 2021     771
# Name: total_units_sold, dtype: int64

# %%
dfsp
# Out:
#       Combined Enterprise Share   Fannie Mae Share  Freddie Mac Share
# year
# 1990                   25.673449         13.985519          11.687930
# 1991                   28.461581         15.833871          12.627710
# 1992                   31.872849         18.133235          13.739615
# 1993                   34.345910         19.658437          14.687473
# 1994                   35.020870         19.976757          15.044113
# 1995                   35.846372         20.615569          15.230803
# 1996                   36.566837         21.120737          15.446100
# 1997                   36.573093         21.326841          15.246252
# 1998                   38.885141         22.909500          15.975641
# 1999                   40.855200         23.797828          17.057372
# 2000                   41.485066         23.905274          17.579792
# 2001                   44.736933         25.880693          18.856240
# ...

# %%
df1
# Out:
#       jan  feb  mar   apr   may   jun   jul  aug  sep   oct  nov  dec   avg
# year
# 2001  4.2  4.2  4.3   4.4   4.3   4.5   4.6  4.9  5.0   5.3  5.5  5.7  4.74
# 2002  5.7  5.7  5.7   5.9   5.8   5.8   5.8  5.7  5.7   5.7  5.9  6.0  5.78
# 2003  5.8  5.9  5.9   6.0   6.1   6.3   6.2  6.1  6.1   6.0  5.8  5.7  5.99
# 2004  5.7  5.6  5.8   5.6   5.6   5.6   5.5  5.4  5.4   5.5  5.4  5.4  5.54
# 2005  5.3  5.4  5.2   5.2   5.1   5.0   5.0  4.9  5.0   5.0  5.0  4.9  5.08
# 2006  4.7  4.8  4.7   4.7   4.6   4.6   4.7  4.7  4.5   4.4  4.5  4.4  4.61
# 2007  4.6  4.5  4.4   4.5   4.4   4.6   4.7  4.6  4.7   4.7  4.7  5.0  4.62
# 2008  5.0  4.9  5.1   5.0   5.4   5.6   5.8  6.1  6.1   6.5  6.8  7.3  5.80
# 2009  7.8  8.3  8.7   9.0   9.4   9.5   9.5  9.6  9.8  10.0  9.9  9.9  9.28
# 2010  9.8  9.8  9.9   9.9   9.6   9.4   9.4  9.5  9.5   9.4  9.8  9.3  9.61
# 2011  9.1  9.0  9.0   9.1   9.0   9.1   9.0  9.0  9.0   8.8  8.6  8.5  8.93
# ...

# %%
ar
# Out:
#      median_price      NE      MW       S       W
# year
# 2001       175200  246400  172600  155400  213600
# 2002       187600  264300  178000  163400  238500
# 2003       195000  264500  184300  168100  260900
# 2004       221000  315800  205000  181100  283100
# 2005       240900  343800  216900  197300  332600
# 2006       246500  346000  213500  208200  337700
# 2007       247900  320200  208600  217700  330900
# 2008       232100  343600  198900  203700  294800
# 2009       216700  302500  189200  194800  263700
# 2010       221800  329900  197700  196800  259300
# 2011       227200  322800  203300  211400  256000
# 2012       245200  368800  230600  227000  270000
# 2013       268900  371200  255300  246600  310500
# 2014       288500  398000  273800  264000  339000
# 2015       294200  442800  276700  271500  348500
# 2016       307800  428300  277100  281400  367700
# 2017       323100  490400  284400  291200  390000
# 2018       326400  484600  290900  294600  410600
# ...

# %%
df2
# Out:
#       total_units_sold   avg
# year
# 2001               908  4.74
# 2002               973  5.78
# 2003              1086  5.99
# 2004              1203  5.54
# 2005              1283  5.08
# 2006              1051  4.61
# 2007               776  4.62
# 2008               485  5.80
# 2009               375  9.28
# 2010               323  9.61
# 2011               306  8.93
# 2012               368  8.08
# 2013               429  7.36
# 2014               437  6.16
# 2015               501  5.28
# 2016               561  4.88
# 2017               613  4.36
# 2018               617  3.89
# 2019               683  3.68
# 2020               822  8.09
# 2021               771  5.36

# %%
rts
# Out:
#             Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# date
# 2004-09-02        5.77         0.8        5.15         0.7        0.00
# 2004-09-09        5.83         0.8        5.22         0.8        0.00
# 2004-09-16        5.75         0.8        5.13         0.8        0.00
# 2004-09-23        5.70         0.7        5.10         0.7        0.00
# 2004-09-30        5.72         0.6        5.12         0.6        0.00
# ...                ...         ...         ...         ...         ...
# 2021-12-02        3.11         0.6        2.39         0.6        2.49
# 2021-12-09        3.10         0.7        2.38         0.7        2.45
# 2021-12-16        3.12         0.6        2.34         0.7        2.45
# 2021-12-23        3.05         0.7        2.30         0.7        2.37
# 2021-12-30        3.11         0.7        2.33         0.7        2.41
#
#             Unnamed: 6  Unnamed: 7  Unnamed: 8       date
# date
# ...

# %%
sq = pd.read_csv('/Users/padminiyadav/Downloads/bedroom.csv')

# %%
sq.head()
# Out:
#   Unnamed: 0 Number of houses (in thousands) Unnamed: 2  Unnamed: 3  \
# 0       Year                           Total  2 or less  3 bedrooms
# 1       1978                             816         74         523
# 2       1979                             709         82         451
# 3       1980                             530         76         339
# 4       1981                             437         84         260
#
#   Unnamed: 4 Percent distribution   Unnamed: 6  Unnamed: 7   Unnamed: 8
# 0  4 or more                Total    2 or less  3 bedrooms    4 or more
# 1        219                  100            9          64           27
# 2        176                  100           12          64           25
# 3        115                  100           14          64           22
# 4         93                  100           19          59           21

# %%
sq.columns = ['Year','Total', '2 or less', '3 bedrooms', '4 or more', 'Totalp',  '2 or lessp', '3 bedroomsp',  '4 or morep']

# %%
sq.drop(index = 0, inplace = True)
sq.drop(index = 45, inplace = True)

# %%
sq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44 entries, 1 to 44
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         44 non-null     object
#  1   Total        44 non-null     object
#  2   2 or less    44 non-null     object
#  3   3 bedrooms   44 non-null     object
#  4   4 or more    44 non-null     object
#  5   Totalp       44 non-null     object
#  6   2 or lessp   44 non-null     object
#  7   3 bedroomsp  44 non-null     object
#  8   4 or morep   44 non-null     object
# dtypes: object(9)
# memory usage: 3.4+ KB

# %%
sq
# Out:
#     Year  Total 2 or less 3 bedrooms 4 or more Totalp 2 or lessp 3 bedroomsp  \
# 1   1978    816        74        523       219    100          9          64
# 2   1979    709        82        451       176    100         12          64
# 3   1980    530        76        339       115    100         14          64
# 4   1981    437        84        260        93    100         19          59
# 5   1982    412        85        246        81    100         21          60
# 6   1983    623       138        363       122    100         22          58
# 7   1984    639       153        365       121    100         24          57
# 8   1985    687       156        394       137    100         23          57
# 9   1986    750       142        437       171    100         19          58
# 10  1987    671       106        387       178    100         16          58
# 11  1988    676        95        383       198    100         14          57
# ...

# %%
sq.at[26, 'Total'] = 1086
sq.at[27, 'Total'] = 1203
sq.at[28, 'Total'] = 1283
sq.at[29, 'Total'] = 1051

# %%
sq
# Out:
#     Year Total 2 or less 3 bedrooms 4 or more Totalp 2 or lessp 3 bedroomsp  \
# 1   1978   816        74        523       219    100          9          64
# 2   1979   709        82        451       176    100         12          64
# 3   1980   530        76        339       115    100         14          64
# 4   1981   437        84        260        93    100         19          59
# 5   1982   412        85        246        81    100         21          60
# 6   1983   623       138        363       122    100         22          58
# 7   1984   639       153        365       121    100         24          57
# 8   1985   687       156        394       137    100         23          57
# 9   1986   750       142        437       171    100         19          58
# 10  1987   671       106        387       178    100         16          58
# 11  1988   676        95        383       198    100         14          57
# ...

# %%
for i in sq:
    sq[f'{i}'] = pd.to_numeric(sq[f'{i}'])

# %%
sq.set_index('Year', inplace = True)

# %%
sq.columns
# Out:
# Index(['Total', '2 or less', '3 bedrooms', '4 or more', 'Totalp', '2 or lessp',
#        '3 bedroomsp', '4 or morep'],
#       dtype='object')

# %%
sqp = sq[['2 or lessp','3 bedroomsp', '4 or morep']]
sq.drop(['2 or lessp','3 bedroomsp', '4 or morep', 'Totalp'], axis = 1, inplace= True)

# %%
plt.figure(figsize = (18,5))
plt.plot(sq)
plt.xticks(range(1978,2022), rotation = 45)
plt.legend(['total bedrooms','2 or less bedrooms', '3 bedrooms', '4 or more bedrooms'])
plt.show()

# %%
sqp.plot(kind='bar', stacked=True, figsize=(16,7))
plt.legend(['2 or less bedrooms', '3 bedooms', '4 or more bedrooms'])
plt.xlabel('year')
plt.ylabel('% of houses')
plt.show()

# %%
data = pd.read_csv('/Users/padminiyadav/Downloads/USA_housing.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
ind=0
for i in data.columns:
    ind+=1
    print(f'{ind}.',i)
# Out:
# 1. Avg. Area Income
# 2. Avg. Area House Age
# 3. Avg. Area Number of Rooms
# 4. Avg. Area Number of Bedrooms
# 5. Area Population
# 6. Price
# 7. Address

# %%
sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
data.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
count 5.000000e+03
mean 1.232073e+06
std 3.531176e+05
min 1.593866e+04
25% 9.975771e+05
50% 1.232669e+06
75% 1.471210e+06
max 2.469066e+06

# %%
data.shape
# Out:
# (5000, 7)

# %%
data.Address = data.Address.apply(lambda row: row.split(' ')[-2])

# %%
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price Address
# 0                          4.09     23086.800503  1.059034e+06      NE
# 1                          3.09     40173.072174  1.505891e+06      CA
# 2                          5.13     36882.159400  1.058988e+06      WI
# 3                          3.26     34310.242831  1.260617e+06      AP
# 4                          4.23     26354.109472  6.309435e+05      AE

# %%
for i in data.columns[:-2]:
    plt.scatter(data.index, data[f'{i}'])
    plt.show()

# %%
data.Address.value_counts().keys()
# Out:
# Index(['AA', 'AP', 'AE', 'GU', 'OR', 'DE', 'NC', 'KY', 'VT', 'AZ', 'VA', 'NE',
#        'ND', 'ID', 'DC', 'PA', 'WV', 'MO', 'IN', 'SD', 'GA', 'NM', 'AS', 'CA',
#        'TX', 'MP', 'NY', 'UT', 'MA', 'MI', 'TN', 'IA', 'OK', 'ME', 'CO', 'FL',
#        'FM', 'WY', 'SC', 'CT', 'PR', 'WA', 'LA', 'OH', 'NH', 'MT', 'RI', 'NJ',
#        'NV', 'PW', 'HI', 'AL', 'MS', 'MH', 'MN', 'AR', 'KS', 'AK', 'WI', 'IL',
#        'MD', 'VI'],
#       dtype='object')

# %%
add = []
for i in range(len(data.Address.value_counts().keys())):
    add.append([data.Address.value_counts().keys()[i],i])

# %%
for i in range(data.shape[0]):
    for j in add:
        if data.at[i,'Address'] == j[0]:
            data.at[i, 'Address'] = j[1]

# %%
data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price Address
# ...

# %%
data.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
scaler = StandardScaler()

# %%
scaled_data = scaler.fit_transform(data[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms','Avg. Area Number of Bedrooms', 'Area Population', 'Price']])

# %%
scaled_data
# Out:
# array([[ 1.02865969, -0.29692705,  0.02127433,  0.08806222, -1.31759867,
#         -0.49008146],
#        [ 1.00080775,  0.02590164, -0.25550611, -0.72230146,  0.40399945,
#          0.77550829],
#        [-0.68462916, -0.11230283,  1.5162435 ,  0.93084045,  0.07240989,
#         -0.49021053],
#        ...,
#        [-0.48723454,  1.28447022, -2.17026949, -1.50025059, -0.29193658,
#         -0.570244  ],
#        [-0.05459152, -0.44669439,  0.14154061,  1.18205319,  0.65111608,
#         -0.0946402 ],
#        [-0.28831272,  0.01521477, -0.19434166,  0.07185495,  1.04162464,
#          0.18941143]])

# %%
plt.boxplot(scaled_data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fd968da4f70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fd948bc6640>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fd968da43a0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7fd948bc6820>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd968dc4a00>,
# ...
#  'means': []}

# %%
scaled_df=pd.DataFrame(scaled_data, columns = data.columns[:-1])

# %%
scaled_df.Price.describe()
# Out:
# count    5.000000e+03
# mean    -1.390943e-16
# std      1.000100e+00
# min     -3.444336e+00
# 25%     -6.641384e-01
# 50%      1.690042e-03
# 75%      6.772856e-01
# max      3.503412e+00
# Name: Price, dtype: float64

# %%
scaled_df['Price_t'] = ''
scaled_df['Price_l'] = ''

# %%
scaled_df['Address']  =data['Address']

# %%
for i in range(scaled_df.shape[0]):
    if scaled_df.loc[i]['Price'] <= -6.641384e-01:
        scaled_df.at[i, 'Price_t'] = 0 #'LOW-Q1'
    elif scaled_df.iloc[i]['Price'] > -6.641384e-01 and scaled_df.iloc[i]['Price'] <= 1.690042e-03:
        scaled_df.at[i, 'Price_t'] = 1 #'LOWERMID-Q2'
    elif scaled_df.iloc[i]['Price'] > 1.690042e-03 and scaled_df.iloc[i]['Price'] < 6.772856e-01:
        scaled_df.at[i, 'Price_t'] = 2 #'UPPERMID-Q3'
    else:
        scaled_df.at[i, 'Price_t'] = 3 #'HIGH_Q'

# %%
for i in range(scaled_df.shape[0]):
    if scaled_df.loc[i]['Price'] <= -6.641384e-01:
        scaled_df.at[i, 'Price_l'] = 'LOW-Q1'
    elif scaled_df.iloc[i]['Price'] > -6.641384e-01 and scaled_df.iloc[i]['Price'] <= 1.690042e-03:
        scaled_df.at[i, 'Price_l'] = 'LOWERMID-Q2'
    elif scaled_df.iloc[i]['Price'] > 1.690042e-03 and scaled_df.iloc[i]['Price'] < 6.772856e-01:
        scaled_df.at[i, 'Price_l'] = 'UPPERMID-Q3'
    else:
        scaled_df.at[i, 'Price_l'] = 'HIGH_Q4'

# %%
scaled_df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0             1.028660            -0.296927                   0.021274
# 1             1.000808             0.025902                  -0.255506
# 2            -0.684629            -0.112303                   1.516243
# 3            -0.491499             1.221572                  -1.393077
# 4            -0.807073            -0.944834                   0.846742
# ...                ...                  ...                        ...
# 4995         -0.752109             1.869297                  -0.845588
# 4996          0.929740             1.030822                  -0.408686
# 4997         -0.487235             1.284470                  -2.170269
# 4998         -0.054592            -0.446694                   0.141541
# 4999         -0.288313             0.015215                  -0.194342
#
#       Avg. Area Number of Bedrooms  Area Population     Price Price_t  \
# ...

# %%
scaled_df.Price_t.value_counts()
# Out:
# 3    1250
# 2    1250
# 1    1250
# 0    1250
# Name: Price_t, dtype: int64

# %%
scaled_df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Price_t',
#        'Price_l', 'Address'],
#       dtype='object')

# %%
x = scaled_df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms','Avg. Area Number of Bedrooms', 'Area Population', 'Address']]
y = scaled_df['Price_l']

# %%
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.20, random_state=0)

# %%
from sklearn.svm import SVC # "Support vector classifier"  
classifier = SVC(kernel='linear', random_state=0)  
classifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred= classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix  
cm= confusion_matrix(y_test, y_pred)

# %%
c = 0
w=0
for i in range(4):
    for j in range(4):
        if i==j:
            c+=cm[i][j]
        else:
            w+=cm[i][j]

svm = (c/(c+w))*100
print('accuracy:' ,(c/(c+w))*100)
# Out:
# accuracy: 78.3

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.25, random_state=0)

# %%
gnb = GaussianNB()

# %%
y_pred = gnb.fit(x_train, y_train).predict(x_test)

# %%
cm= confusion_matrix(y_test, y_pred)

# %%
c = 0
w=0
for i in range(4):
    for j in range(4):
        if i==j:
            c+=cm[i][j]
        else:
            w+=cm[i][j]

nbg = (c/(c+w))*100        
print('accuracy:' ,(c/(c+w))*100)
# Out:
# accuracy: 71.67999999999999

# %%
from xgboost import XGBClassifier

# %%
x.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Address'],
#       dtype='object')

# %%
x = scaled_df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms','Avg. Area Number of Bedrooms', 'Area Population']]
y = scaled_df['Price_t']
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.20, random_state=0)

# %%
model = XGBClassifier()
model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...)

# %%
y_pred = model.predict(x_test)
predictions = [value for value in y_pred]

# %%
c=0
w=0
for i in range(len(y_test)):
    if predictions[i] == y_test.values[i]:
        c+=1
    else:
        w+=1

xgb = (c/(c+w))*100        
print('accuracy: ', (c/(c+w))*100)
# Out:
# accuracy:  71.6

# %%
cust = pd.read_csv('/Users/padminiyadav/Downloads/house.csv')
cust.shape
cust.info()
cust['Occupancy Code'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2034702 entries, 0 to 2034701
# Data columns (total 39 columns):
#  #   Column                                      Dtype
# ---  ------                                      -----
#  0   Enterprise Flag                             int64
#  1   Record Number                               int64
#  2   US Postal State Code                        int64
#  3   Metropolitan Statistical Area (MSA) Code    int64
#  4   County - 2010 Census                        int64
#  5   Census Tract - 2010 Census                  int64
#  6   2010 Census Tract - Percent Minority        float64
#  7   2010 Census Tract - Median Income           int64
#  8   Local Area Median Income                    int64
#  9   Tract Income Ratio                          float64
#  10  Borrower's (or Borrowers') Annual Income    int64
#  11  Area Median Family Income (2012)            int64
#  12  Borrower Income Ratio                       float64
# ...

# %%
cust.head(1).T
# Out:
#                                                       0
# Enterprise Flag                                  2.0000
# Record Number                                    1.0000
# US Postal State Code                             6.0000
# Metropolitan Statistical Area (MSA) Code     31100.0000
# County - 2010 Census                            37.0000
# Census Tract - 2010 Census                  910805.0000
# 2010 Census Tract - Percent Minority            26.3100
# 2010 Census Tract - Median Income           104063.0000
# Local Area Median Income                     66502.0000
# Tract Income Ratio                               1.5648
# Borrower's (or Borrowers') Annual Income    104000.0000
# Area Median Family Income (2012)             70100.0000
# Borrower Income Ratio                            1.4836
# Acquisition Unpaid Principal Balance (UPB)  404000.0000
# Purpose of Loan                                  1.0000
# Federal Guarantee                                1.0000
# ...

# %%
cust['Borrower Gender'].value_counts()
# Out:
# 1    1451169
# 2     485752
# 3      91189
# 9       6472
# 4        120
# Name: Borrower Gender, dtype: int64

# %% [markdown]
# ## RENTALS

# %%
hs = pd.read_csv('/Users/padminiyadav/Downloads/housing.csv')

# %%
hs.shape
# Out:
# (384977, 22)

# %%
hs.dropna(how='all')
# Out:
#                 id                                                url  \
# 0       7049044568  https://reno.craigslist.org/apa/d/reno-beautif...
# 1       7049047186  https://reno.craigslist.org/apa/d/reno-reduced...
# 2       7043634882  https://reno.craigslist.org/apa/d/sparks-state...
# 3       7049045324  https://reno.craigslist.org/apa/d/reno-1x1-fir...
# 4       7049043759  https://reno.craigslist.org/apa/d/reno-no-long...
# ...            ...                                                ...
# 384972  7049053337  https://reno.craigslist.org/apa/d/reno-2x2-thi...
# 384973  7049052968  https://reno.craigslist.org/apa/d/sparks-over-...
# 384974  7049050454  https://reno.craigslist.org/apa/d/sparks-1mont...
# 384975  7049050149  https://reno.craigslist.org/apa/d/sparks-ready...
# 384976  7049050010  https://reno.craigslist.org/apa/d/reno-2x2-thi...
#
#               region                   region_url  price       type  sqfeet  \
# ...

# %%
hs.head()
# Out:
#            id                                                url  \
# 0  7049044568  https://reno.craigslist.org/apa/d/reno-beautif...
# 1  7049047186  https://reno.craigslist.org/apa/d/reno-reduced...
# 2  7043634882  https://reno.craigslist.org/apa/d/sparks-state...
# 3  7049045324  https://reno.craigslist.org/apa/d/reno-1x1-fir...
# 4  7049043759  https://reno.craigslist.org/apa/d/reno-no-long...
#
#          region                   region_url  price       type  sqfeet  beds  \
# 0  reno / tahoe  https://reno.craigslist.org   1148  apartment    1078     3
# 1  reno / tahoe  https://reno.craigslist.org   1200      condo    1001     2
# 2  reno / tahoe  https://reno.craigslist.org   1813  apartment    1683     2
# 3  reno / tahoe  https://reno.craigslist.org   1095  apartment     708     1
# 4  reno / tahoe  https://reno.craigslist.org    289  apartment     250     0
#
#    baths  cats_allowed  ...  wheelchair_access  electric_vehicle_charge  \
# ...

# %%
hs.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'type', 'sqfeet', 'beds',
#        'baths', 'cats_allowed', 'dogs_allowed', 'smoking_allowed',
#        'wheelchair_access', 'electric_vehicle_charge', 'comes_furnished',
#        'laundry_options', 'parking_options', 'image_url', 'description', 'lat',
#        'long', 'state'],
#       dtype='object')

# %%
hs.drop(['region','id', 'url','region_url','image_url','lat','long','description'], axis = 1, inplace= True)

# %%
hs.head()
# Out:
#    price       type  sqfeet  beds  baths  cats_allowed  dogs_allowed  \
# 0   1148  apartment    1078     3    2.0             1             1
# 1   1200      condo    1001     2    2.0             0             0
# 2   1813  apartment    1683     2    2.0             1             1
# 3   1095  apartment     708     1    1.0             1             1
# 4    289  apartment     250     0    1.0             1             1
#
#    smoking_allowed  wheelchair_access  electric_vehicle_charge  \
# 0                0                  0                        0
# 1                0                  0                        0
# 2                1                  0                        0
# 3                1                  0                        0
# 4                1                  1                        0
#
#    comes_furnished  laundry_options  parking_options state
# 0                0      w/d in unit          carport    ca
# ...

# %%
hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384977 entries, 0 to 384976
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   price                    384977 non-null  int64
#  1   type                     384977 non-null  object
#  2   sqfeet                   384977 non-null  int64
#  3   beds                     384977 non-null  int64
#  4   baths                    384977 non-null  float64
#  5   cats_allowed             384977 non-null  int64
#  6   dogs_allowed             384977 non-null  int64
#  7   smoking_allowed          384977 non-null  int64
#  8   wheelchair_access        384977 non-null  int64
#  9   electric_vehicle_charge  384977 non-null  int64
#  10  comes_furnished          384977 non-null  int64
#  11  laundry_options          305951 non-null  object
#  12  parking_options          244290 non-null  object
# ...

# %%
hs.laundry_options.value_counts()
# Out:
# w/d in unit           131783
# w/d hookups            75568
# laundry on site        58873
# laundry in bldg        36103
# no laundry on site      3624
# Name: laundry_options, dtype: int64

# %%
ld = []
for i in range(len(hs.laundry_options.value_counts().keys())):
    ld.append([hs.laundry_options.value_counts().keys()[i],i])
    
for i in range(hs.shape[0]):
    for j in ld:
        if hs.at[i,'laundry_options'] == j[0]:
            hs.at[i, 'laundry_options'] = j[1]

# %%
ld = []
for i in range(len(hs.type.value_counts().keys())):
    ld.append([hs.type.value_counts().keys()[i],i])
    
for i in range(hs.shape[0]):
    for j in ld:
        if hs.at[i,'type'] == j[0]:
            hs.at[i, 'type'] = j[1]

# %%
ld = []
for i in range(len(hs.parking_options.value_counts().keys())):
    ld.append([hs.parking_options.value_counts().keys()[i],i])
    
for i in range(hs.shape[0]):
    for j in ld:
        if hs.at[i,'parking_options'] == j[0]:
            hs.at[i, 'parking_options'] = j[1]

# %%
ld = []
for i in range(len(hs.state.value_counts().keys())):
    ld.append([hs.state.value_counts().keys()[i],i])
    
for i in range(hs.shape[0]):
    for j in ld:
        if hs.at[i,'state'] == j[0]:
            hs.at[i, 'state'] = j[1]

# %%
hs.columns
# Out:
# Index(['price', 'type', 'sqfeet', 'beds', 'baths', 'cats_allowed',
#        'dogs_allowed', 'smoking_allowed', 'wheelchair_access',
#        'electric_vehicle_charge', 'comes_furnished', 'laundry_options',
#        'parking_options', 'state'],
#       dtype='object')

# %%
a = 0
for i in hs.columns:
    a+=1
    print(f'{a}.',i)
# Out:
# 1. price
# 2. type
# 3. sqfeet
# 4. beds
# 5. baths
# 6. cats_allowed
# 7. dogs_allowed
# 8. smoking_allowed
# 9. wheelchair_access
# 10. electric_vehicle_charge
# 11. comes_furnished
# 12. laundry_options
# 13. parking_options
# 14. state
# 15. Price_t
# 16. Price_l

# %%
for i in ['type', 'laundry_options', 'parking_options', 'state']:
    hs[f'{i}'] = pd.to_numeric(hs[f'{i}'])

# %%
hs.fillna(9, inplace= True)

# %%
hs.drop(hs[hs['price']>10000].index, inplace=True)

# %%
plt.boxplot(hs.price)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fd9109eabe0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fd9109f42e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fd9109ea880>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd9109f49a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd9109f4d00>],
#  'means': []}

# %%
hs.price.describe()
# Out:
# count    384708.000000
# mean       1180.175102
# std         597.079504
# min           0.000000
# 25%         805.000000
# 50%        1035.000000
# 75%        1395.000000
# max       10000.000000
# Name: price, dtype: float64

# %%
hs.iloc[1988]
# Out:
# price                      1724.0
# type                          0.0
# sqfeet                     1040.0
# beds                          2.0
# baths                         2.0
# cats_allowed                  1.0
# dogs_allowed                  1.0
# smoking_allowed               1.0
# wheelchair_access             0.0
# electric_vehicle_charge       0.0
# comes_furnished               0.0
# laundry_options               1.0
# parking_options               3.0
# state                         0.0
# Price_t                       0.0
# Name: 1989, dtype: float64

# %%
hs.price.fillna(0, inplace=True)

# %%
hs.describe()
# Out:
#                price           type        sqfeet           beds  \
# count  384708.000000  384708.000000  3.847080e+05  384708.000000
# mean     1180.175102       0.365451  1.056703e+03       1.904691
# std       597.079504       1.019958  1.908685e+04       3.495482
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%       805.000000       0.000000  7.500000e+02       1.000000
# 50%      1035.000000       0.000000  9.490000e+02       2.000000
# 75%      1395.000000       0.000000  1.150000e+03       2.000000
# max     10000.000000      11.000000  8.388607e+06    1100.000000
#
#                baths   cats_allowed   dogs_allowed  smoking_allowed  \
# count  384708.000000  384708.000000  384708.000000    384708.000000
# mean        1.480220       0.726954       0.707966         0.731724
# std         0.616998       0.445525       0.454699         0.443063
# min         0.000000       0.000000       0.000000         0.000000
# ...

# %%
price_t = []
price_l = []
for i in hs.price.values:
    if i <= 805:
        price_t.append('Q1')
        price_l.append(0)
    elif i> 805 and i<=1035:
        price_t.append('Q2')
        price_l.append(1)
    elif i>1035 and i<1395:
        price_t.append('Q3')
        price_l.append(2)
    else:
        price_t.append('Q4')
        price_l.append(3)

# %%
hs.Price_t = price_t

# %%
hs.price_l = price_l

# %%
hs.columns
# Out:
# Index(['price', 'type', 'sqfeet', 'beds', 'baths', 'cats_allowed',
#        'dogs_allowed', 'smoking_allowed', 'wheelchair_access',
#        'electric_vehicle_charge', 'comes_furnished', 'laundry_options',
#        'parking_options', 'state', 'Price_t'],
#       dtype='object')

# %%
hs
# Out:
#         price  type  sqfeet  beds  baths  cats_allowed  dogs_allowed  \
# 0        1148     0    1078     3    2.0             1             1
# 1        1200     3    1001     2    2.0             0             0
# 2        1813     0    1683     2    2.0             1             1
# 3        1095     0     708     1    1.0             1             1
# 4         289     0     250     0    1.0             1             1
# ...       ...   ...     ...   ...    ...           ...           ...
# 384972   1295     0     957     2    2.0             1             1
# 384973   1549     0    1034     2    2.0             1             1
# 384974   1249     0     840     2    1.0             1             1
# 384975   1429     0     976     2    2.0             1             1
# 384976   1295     0     957     2    2.0             1             1
#
#         smoking_allowed  wheelchair_access  electric_vehicle_charge  \
# 0                     0                  0                        0
# ...

# %%
hs.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
x_test.fillna(x_train.mean(), inplace=True)

# %%
hs.dropna(how='all')
# Out:
#         price  type  sqfeet  beds  baths  cats_allowed  dogs_allowed  \
# 0        1148     0    1078     3    2.0             1             1
# 1        1200     3    1001     2    2.0             0             0
# 2        1813     0    1683     2    2.0             1             1
# 3        1095     0     708     1    1.0             1             1
# 4         289     0     250     0    1.0             1             1
# ...       ...   ...     ...   ...    ...           ...           ...
# 384972   1295     0     957     2    2.0             1             1
# 384973   1549     0    1034     2    2.0             1             1
# 384974   1249     0     840     2    1.0             1             1
# 384975   1429     0     976     2    2.0             1             1
# 384976   1295     0     957     2    2.0             1             1
#
#         smoking_allowed  wheelchair_access  electric_vehicle_charge  \
# 0                     0                  0                        0
# ...

# %%
hs
# Out:
#         price  type  sqfeet  beds  baths  cats_allowed  dogs_allowed  \
# 0        1148     0    1078     3    2.0             1             1
# 1        1200     3    1001     2    2.0             0             0
# 2        1813     0    1683     2    2.0             1             1
# 3        1095     0     708     1    1.0             1             1
# 4         289     0     250     0    1.0             1             1
# ...       ...   ...     ...   ...    ...           ...           ...
# 384972   1295     0     957     2    2.0             1             1
# 384973   1549     0    1034     2    2.0             1             1
# 384974   1249     0     840     2    1.0             1             1
# 384975   1429     0     976     2    2.0             1             1
# 384976   1295     0     957     2    2.0             1             1
#
#         smoking_allowed  wheelchair_access  electric_vehicle_charge  \
# 0                     0                  0                        0
# ...

# %%
hs['Price_t'].value_counts()
# Out:
# Q4    97433
# Q1    96245
# Q2    96201
# Q3    94829
# Name: Price_t, dtype: int64

# %%
hs['Price_l'] = price_l

# %%
x_hs = hs[['type', 'sqfeet', 'beds', 'baths', 'cats_allowed','dogs_allowed', 'smoking_allowed', 'wheelchair_access','electric_vehicle_charge', 'comes_furnished', 'laundry_options','parking_options', 'state']]

y_hs = hs.Price_l

x_train, x_test, y_train, y_test= train_test_split(x_hs, y_hs, test_size= 0.20, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rdm = RandomForestRegressor()

# %%
rdm.fit(x_train, y_train)
rdm.score(x_test, y_test)*100
# Out:
# 81.73458476708136

# %%
from sklearn import metrics
print('R^2:',metrics.r2_score(y_test, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_pred))*(len(y_train)-1)/(len(y_train)-x_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R^2: -1141918.3088434958
# Adjusted R^2: -1141966.5455763682
# MAE: 1177.5027686809678
# MSE: 1431224.446327039
# RMSE: 1196.3379314922013

# %%
from sklearn.neighbors import KNeighborsClassifier
X_train, X_test, y_train, y_test = train_test_split(x_hs, y_hs, test_size=0.25, random_state=142)
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
prediction_results = knn.predict(X_test)

# %%
prediction_results
# Out:
# array([0, 2, 0, ..., 2, 2, 1])

# %%
c=0
w=0
for i in range(len(prediction_results)):
    if prediction_results[i]==y_test.values[i]:
        c+=1
    else:
        w+=1
        
print(c/(c+w)*100)
# Out:
# 77.78782869085124

# %% [markdown]
# ### LOANS

# %%
loan = pd.read_csv('/Users/padminiyadav/Downloads/loans.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (15,16,17,31,32,33,34,42,43,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
loan.head()
# Out:
#    action_taken action_taken_name  agency_code agency_abbr  \
# 0             1   Loan originated            9        CFPB
# 1             1   Loan originated            9        CFPB
# 2             1   Loan originated            7         HUD
# 3             1   Loan originated            9        CFPB
# 4             1   Loan originated            9        CFPB
#
#                                    agency_name  applicant_ethnicity  \
# 0         Consumer Financial Protection Bureau                    2
# 1         Consumer Financial Protection Bureau                    2
# 2  Department of Housing and Urban Development                    2
# 3         Consumer Financial Protection Bureau                    2
# 4         Consumer Financial Protection Bureau                    2
#
#   applicant_ethnicity_name  applicant_income_000s  applicant_race_1  \
# 0   Not Hispanic or Latino                   97.0                 5
# ...

# %%
loan.shape
# Out:
# (439654, 78)

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439654 entries, 0 to 439653
# Data columns (total 78 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   action_taken                    439654 non-null  int64
#  1   action_taken_name               439654 non-null  object
#  2   agency_code                     439654 non-null  int64
#  3   agency_abbr                     439654 non-null  object
#  4   agency_name                     439654 non-null  object
#  5   applicant_ethnicity             439654 non-null  int64
#  6   applicant_ethnicity_name        439654 non-null  object
#  7   applicant_income_000s           378651 non-null  float64
#  8   applicant_race_1                439654 non-null  int64
#  9   applicant_race_2                1610 non-null    float64
#  10  applicant_race_3                87 non-null      float64
#  11  applicant_race_4                15 non-null      float64
# ...

# %%
loan['action_taken'].value_counts()
loan['action_taken_name'].value_counts()
# Out:
# Loan originated                                        228054
# Application denied by financial institution             79697
# Loan purchased by the institution                       61490
# Application withdrawn by applicant                      39496
# File closed for incompleteness                          16733
# Application approved but not accepted                   14180
# Preapproval request denied by financial institution         4
# Name: action_taken_name, dtype: int64

# %%
loan['applicant_race_name_1'].value_counts()
# Out:
# White                                                                                283335
# Not applicable                                                                        50491
# Information not provided by applicant in mail, Internet, or telephone application     46279
# Black or African American                                                             28687
# Asian                                                                                 27890
# American Indian or Alaska Native                                                       1712
# Native Hawaiian or Other Pacific Islander                                              1260
# Name: applicant_race_name_1, dtype: int64

# %%
pd.DataFrame(loan.groupby('applicant_race_name_1')['action_taken_name'].value_counts())
# Out:
#                                                                                                        action_taken_name
# applicant_race_name_1                              action_taken_name
# American Indian or Alaska Native                   Loan originated                                                   670
#                                                    Application denied by financial institution                       659
#                                                    Application withdrawn by applicant                                173
#                                                    File closed for incompleteness                                    106
#                                                    Application approved but not accepted                              56
#                                                    Loan purchased by the institution                                  48
# ...

# %%
loan['applicant_race_name_1'].value_counts()
# Out:
# White                                                                                283335
# Not applicable                                                                        50491
# Information not provided by applicant in mail, Internet, or telephone application     46279
# Black or African American                                                             28687
# Asian                                                                                 27890
# American Indian or Alaska Native                                                       1712
# Native Hawaiian or Other Pacific Islander                                              1260
# Name: applicant_race_name_1, dtype: int64

# %%
pd.DataFrame(loan.groupby('applicant_ethnicity_name')['action_taken_name'].value_counts())
# Out:
#                                                                                                        action_taken_name
# applicant_ethnicity_name                           action_taken_name
# Hispanic or Latino                                 Loan originated                                                 12231
#                                                    Application denied by financial institution                      6314
#                                                    Application withdrawn by applicant                               2835
#                                                    Loan purchased by the institution                                1488
#                                                    File closed for incompleteness                                   1253
#                                                    Application approved but not accepted                             952
# ...

# %%
loan['applicant_ethnicity_name'].value_counts()
# Out:
# Not Hispanic or Latino                                                               320515
# Not applicable                                                                        50708
# Information not provided by applicant in mail, Internet, or telephone application     43358
# Hispanic or Latino                                                                    25073
# Name: applicant_ethnicity_name, dtype: int64

# %%
lat = (6413+1253+2853+952)/25073

# %%
wh = (51204+9927+26553+10068)/283335
nh = (379+29+139+66)/1260
bl = (8500+1136+1610+3217)/28687
an = (5403+1125+3029+1336)/27890
ai = (659+56+173+106)/1712

# %%
print('% of applicants from races who dont get home loan they applied for'.upper())
print('White: ',round(wh*100,2), '%')
print('Native Hawaiian or Other Pacific Islander: ',round(nh*100,2),'%')
print('Black or African American: ',round(bl*100,2),'%')
print('Asian: ',round(an*100,2),'%')
print('American Indian or Alaska Native: ',round(ai*100,2),'%')
print('(ethnicity) : Hispanic or Latino:',round(lat*100,2),'%')
# Out:
# % OF APPLICANTS FROM RACES WHO DONT GET HOME LOAN THEY APPLIED FOR
# White:  34.5 %
# Native Hawaiian or Other Pacific Islander:  48.65 %
# Black or African American:  50.42 %
# Asian:  39.06 %
# American Indian or Alaska Native:  58.06 %
# (ethnicity) : Hispanic or Latino: 45.75 %

# %%
tloan = loan[['applicant_race_1','applicant_ethnicity', 'applicant_income_000s','action_taken']]

# %%
tloan.fillna(0.0, inplace=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
lt = list(tloan.action_taken.values)
for i in lt:
    if i in [2,3,4,5,7]:
        i = 0
    else:
        i =1

# %%
tloan['loan_result'] = lt
# Out:
# <ipython-input-542-c56cb7008f85>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tloan['loan_result'] = lt

# %%
X  = tloan[['applicant_race_1','applicant_ethnicity','applicant_income_000s']]
y = tloan['loan_result']

# %%
x_train, x_test, y_train, y_test= train_test_split(X, y, test_size= 0.28, random_state=0)

# %%
gnb = GaussianNB()
y_pred = gnb.fit(x_train, y_train).predict(x_test)
cm= confusion_matrix(y_test, y_pred) 
c = 0
w=0
for i in range(4):
    for j in range(4):
        if i==j:
            c+=cm[i][j]
        else:
            w+=cm[i][j]

nbg = (c/(c+w))*100        
print('accuracy:' ,(c/(c+w))*100)
# Out:
# accuracy: 63.394225362981906

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression(random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(x_test)

# %%
cm= confusion_matrix(y_test, y_pred) 
c = 0
w=0
for i in range(4):
    for j in range(4):
        if i==j:
            c+=cm[i][j]
        else:
            w+=cm[i][j]

logr = (c/(c+w))*100        
print('accuracy log-r:' ,logr)
# Out:
# accuracy log-r: 63.45231697738829
